# %% [markdown]
# # <h1 style="line-height:0px;">Crunch It!  <span style="font-size:18px;color:#999">by Kate Rushton and Prabha Matta</span></h1>

# %% [markdown]
# Crunch It! is a Python-driven exploration of Crunchbase, a database of technology companies.

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">1 / Introduction</h1>

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">About Crunchbase</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# What is included in the dataset, how often it can be downloaded and where from, licensing terms

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Project Goals</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# What we we intend to show the reader.

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %%
import numpy as np
import scipy as sp

from pylab import figure, show
from pandas import DataFrame, Series
import pandas as pd

# %pylab inline
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
try:
    import mpld3
    from mpld3 import enable_notebook
    from mpld3 import plugins
    enable_notebook()
except Exception as e:
    print "Attempt to import and enable mpld3 failed", e
mpld3.enable_notebook()

# %%
try:
    import seaborn as sns
except Exception as e:
    print "Attempt to import and enable seaborn failed", e

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">2 / Loading and Cleaning Data</h1>

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Companies</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %%
# Loading All companies dataset
all_companies = pd.read_csv('crunchbase_monthly_export_companies.csv')

#cleanup NaN cells
all_companies = all_companies.fillna(0)
#convert into int cells

all_companies['funding_total_usd'] = all_companies[' funding_total_usd '].apply(lambda x: int(str(x).strip().replace(',', '')))
all_companies['funding_rounds'] = all_companies['funding_rounds'].apply(lambda x: int(x))
all_companies['founded_year'] = all_companies['founded_year'].apply(lambda x: int(x))
all_companies.head(10)
# Out:
#                     permalink                name  \
# 0   /company/canal-do-credito    Canal do Credito
# 1            /company/waywire            #waywire
# 2  /company/tv-communications  &TV Communications
# 3   /company/in-touch-network   (In)Touch Network
# 4            /company/n-plusn          +n (PlusN)
# 5       /company/club-domains       .Club Domains
# 6       /company/fox-networks       .Fox Networks
# 7            /company/0-6-com             0-6.com
# 8             /company/0xdata              0xdata
# 9      /company/1-800-dentist       1-800-DENTIST
#
#                        homepage_url category_code  funding_total_usd   \
# 0  http://www.canaldocredito.com.br       finance            750,000
# 1            http://www.waywire.com          news          1,750,000
# 2             http://enjoyandtv.com   games_video          4,000,000
# 3     http://www.InTouchNetwork.com     ecommerce          1,500,000
# 4                  http://plusn.com      software            600,000
# 5                http://dotclub.com      software          7,000,000
# 6             http://www.dotfox.com   advertising          4,912,394
# 7                http://www.0-6.com           web          2,000,000
# 8             http://www.0xdata.com     analytics          1,700,000
# 9        http://www.1800dentist.com        health                   0
#
#       status country_code state_code           region            city  \
# 0  operating          BRA          0   Belo Horizonte  Belo Horizonte
# 1   acquired          USA         NY         New York        New York
# 2  operating          USA         CA      Los Angeles     Los Angeles
# 3  operating          GBR          0           London          London
# 4  operating          USA         NY         New York        New York
# 5  operating          USA         FL  Fort Lauderdale    Oakland Park
# 6     closed          ARG          0     Buenos Aires    Buenos Aires
# 7  operating            0          0          unknown               0
# 8  operating          USA         CA           SF Bay   Mountain View
# 9  operating          USA         CA      Los Angeles     Los Angeles
#
#    funding_rounds  founded_at  founded_month  founded_quarter  founded_year  \
# 0               1           0               0               0             0
# 1               1    6/1/2012        2012-06          2012-Q2          2012
# 2               2           0               0               0             0
# 3               1    4/1/2011        2011-04          2011-Q2          2011
# 4               1    1/1/2012        2012-01          2012-Q1          2012
# 5               1  10/10/2011        2011-10          2011-Q4          2011
# 6               1           0               0               0             0
# 7               1    1/1/2007        2007-01          2007-Q1          2007
# 8               1    1/1/2011        2011-01          2011-Q1          2011
# 9               1    1/1/1986        1986-01          1986-Q1          1986
#
#   first_funding_at last_funding_at last_milestone_at  funding_total_usd
# 0         1/1/2010        1/1/2010                 0             750000
# 1        6/30/2012       6/30/2012        10/17/2013            1750000
# 2         6/4/2010       9/23/2010                 0            4000000
# 3         4/1/2011        4/1/2011        11/15/2013            1500000
# 4        8/29/2012       8/29/2012                 0             600000
# 5        5/31/2013       5/31/2013                 0            7000000
# 6        1/16/2007       1/16/2007          7/1/2008            4912394
# 7        3/19/2008       3/19/2008                 0            2000000
# 8         1/3/2013        1/3/2013          1/1/2012            1700000
# 9        8/19/2010       8/19/2010         8/19/2010                  0
#
# [10 rows x 19 columns]

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Acquisitions</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %%
# Loading Acquired companies dataset
acquired_companies = pd.read_csv('crunchbase_monthly_export_acquisitions.csv')
acquired_companies = acquired_companies.fillna(0)
acquired_companies['price_amount'] = acquired_companies[' price_amount ']

#Exploring companies which are aquired/ipo (successful extit)
exited_companies = all_companies[all_companies['status'].isin(['acquired','ipo'])].fillna(0)


# len(all_companies) #54294  
# len(acquired_companies) # 10114  
# len(exited_companies) #3556 

# Q. Why inconsistency between aquired and exited companies? Shouldn't exited = acquired + ipo?
# Need to look into it

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Investments</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">3 / What's In the Dataset?</h1>

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Acquisitions</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# Sample Aquisitions data

# %%
acquired_companies.head(10)
# Out:
#                                    company_permalink  \
# 0                                   /company/waywire
# 1                             /company/fluff-friends
# 2                       /company/1-nation-technology
# 3  /company/1-stop-financial-service-centers-of-a...
# 4                          /company/1-800-contacts-2
# 5                              /company/1000-markets
# 6                              /company/1000memories
# 7                                   /company/100plus
# 8                                    /company/10best
# 9                                    /company/10east
#
#                                   company_name company_category_code  \
# 0                                     #waywire                  news
# 1                               (fluff)Friends                     0
# 2                          1 Nation Technology                     0
# 3  1 Stop Financial Service Centers of America                     0
# 4                               1-800 Contacts                     0
# 5                                 1000 Markets             ecommerce
# 6                                 1000memories                   web
# 7                                      100Plus             analytics
# 8                                       10best                   web
# 9                                       10East       network_hosting
#
#   company_country_code company_state_code company_region   company_city  \
# 0                  USA                 NY       New York       New York
# 1                    0                  0        unknown              0
# 2                    0                  0        unknown              0
# 3                  USA                 TX         Austin     Round Rock
# 4                    0                  0        unknown              0
# 5                    0                  0        unknown              0
# 6                  USA                 CA         SF Bay  San Francisco
# 7                  USA                 CA         SF Bay  San Francisco
# 8                  USA                 SC     Greenville     Greenville
# 9                  USA                 FL   Jacksonville   Jacksonville
#
#                acquirer_permalink           acquirer_name  \
# 0                /company/magnify                 Magnify
# 1  /company/social-gaming-network   Social Gaming Network
# 2                 /company/vology                  Vology
# 3         /company/confie-seguros          Confie Seguros
# 4  /company/thomas-h-lee-partners  Thomas H. Lee Partners
# 5               /company/bonanzle                 Bonanza
# 6           /company/ancestry-com                Ancestry
# 7        /company/practice-fusion         Practice Fusion
# 8             /company/nile-guide               NileGuide
# 9     /company/railcar-management      Railcar Management
#
#   acquirer_category_code acquirer_country_code acquirer_state_code  \
# 0            games_video                   USA                  NY
# 1            games_video                   USA                  CA
# 2                  other                     0                   0
# 3             enterprise                   USA                  CA
# 4                      0                   USA                  MA
# 5              ecommerce                   USA                  WA
# 6              ecommerce                   USA                  UT
# 7                 health                   USA                  CA
# 8                 social                   USA                  CA
# 9             enterprise                     0                   0
#
#   acquirer_region  acquirer_city acquired_at acquired_month acquired_quarter  \
# 0        New York       New York  10/17/2013        2013-10          2013-Q4
# 1     Los Angeles  Beverly Hills   9/16/2008        2008-09          2008-Q3
# 2         unknown              0    1/1/2006        2006-01          2006-Q1
# 3     Los Angeles     Buena Park    2/3/2014        2014-02          2014-Q1
# 4          Boston         Boston    1/7/2014        2014-01          2014-Q1
# 5         Seattle        Seattle   9/22/2012        2012-09          2012-Q3
# 6  Salt Lake City          Provo   10/3/2012        2012-10          2012-Q4
# 7          SF Bay  San Francisco   2/27/2013        2013-02          2013-Q1
# 8          SF Bay  San Francisco   1/25/2011        2011-01          2011-Q1
# 9         unknown              0   4/14/2009        2009-04          2009-Q2
#
#    acquired_year  price_amount  price_currency_code
# 0           2013              0                 USD ...
# 1           2008              0                 USD ...
# 2           2006              0                 USD ...
# 3           2014              0                 USD ...
# 4           2014              0                 USD ...
# 5           2012              0                 USD ...
# 6           2012              0                 USD ...
# 7           2013              0                 USD ...
# 8           2011              0                 USD ...
# 9           2009              0                 USD ...
#
# [10 rows x 21 columns]

# %% [markdown]
# Length of dataset (number)

# %%
len(acquired_companies) # 10114
# Out:
# 10114

# %% [markdown]
# Acquisitions over time ( y = count, x = acquired_year)

# %%
acquired_companies['acquired_year'] = acquired_companies['acquired_year'].apply(int)

grpby_acq_time = acquired_companies.groupby('acquired_year').count()
grpby_acq_time.sort('acquired_year',ascending=False).head(10).plot(legend=False,title="number of funding rounds companies had before exiting", kind="bar")

#NEED TO WORK ON THIS ----how to make years in descending order
# Out:
# /Users/prabha/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in text/html formatter: 'BlendedGenericTransform' object has no attribute 'contains_branch'
#   FormatterWarning,

# %% [markdown]
# Histogram for # of employees (x=number of employees, y = count of acquisitions)

# %%
#number of employees is missing in the dataset??

# %% [markdown]
# How many of the acquisitions have pricing data available to us? Pie chart of yes/no

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Companies</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# Length of dataset (number)

# %% [markdown]
# Active vs. not active (pie chart where x = active status, y = count of companies)

# %% [markdown]
# Histogram for # of employees (x=number of employees, y = count of companies

# %% [markdown]
# <h2 style="font-size:15px; line-height:0px">Investments</h2><hr style="line-height:0px;margin-bottom:-10px"/>

# %% [markdown]
# Length of dataset (number)

# %% [markdown]
# Funding events over time (y = count, x = funding_date)

# %% [markdown]
# Investments by stage (funding_round in investments.csv) pie chart

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">4 / Location</h1>

# %% [markdown]
# Top states for acquisitions (x = state, y = count of acquisitions, limit = 20, bar)

# %%
#Top 10 states for doing startups
 
grpby_state = acquired_companies.groupby('company_state_code').count()
grpby_state.sort('company_state_code',ascending=False).head(20)[1:].plot(legend=False,title="Top 10 states for doing startups", kind = "bar")

#State '0' ---> the companies without any state in the database

# %% [markdown]
# Top cities for acquisitions (x = city, y = count of acquisitions, limit = 20, bar)

# %%
#Top 10 cities for doing startups

grpby_city = acquired_companies.groupby('company_city').count()
grpby_city.sort('company_city',ascending=False).head(20)[1:].plot(legend=False,title="Top 10 cities for doing startups", kind="bar")
plt.xticks(rotation=45)
#City '0' ---> the companies without any city in the database. Eliminated
# Out:
# (array([  0.625,   1.625,   2.625,   3.625,   4.625,   5.625,   6.625,
#           7.625,   8.625,   9.625,  10.625,  11.625,  12.625,  13.625,
#          14.625,  15.625,  16.625,  17.625,  18.625]),
#  <a list of 19 Text xticklabel objects>)

# %% [markdown]
# Top cities for funding amount (x = city, y = amount of funding, limit = 10, bar)

# %%
grpby_city_funding = all_companies.groupby('city').sum()
grpby_city_funding.head(10)
grpby_city_funding.sort('funding_total_usd',ascending=False).head(10).plot(legend=False,title="Top 10 cities for funding amount", kind="bar")
plt.xticks(rotation=45)
# Out:
# (array([ 0.625,  1.625,  2.625,  3.625,  4.625,  5.625,  6.625,  7.625,
#          8.625,  9.625]), <a list of 10 Text xticklabel objects>)

# %% [markdown]
# Map visualization (if we have time)

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">4 / Category</h1>

# %% [markdown]
# Top categories for acquisitions (x = category, y = count of acquisitions, limit = 20, bar)

# %%
acquired_companies.head(10)
grpby_category = acquired_companies.groupby('company_category_code').count()
grpby_category.sort('company_category_code',ascending=False).head(20)[1:].plot(legend=False,title="Top 10 categories in acquisitions", kind="bar")
plt.xticks(rotation=45)
# Out:
# (array([  0.625,   1.625,   2.625,   3.625,   4.625,   5.625,   6.625,
#           7.625,   8.625,   9.625,  10.625,  11.625,  12.625,  13.625,
#          14.625,  15.625,  16.625,  17.625,  18.625]),
#  <a list of 19 Text xticklabel objects>)

# %% [markdown]
# Total funding by category (top 10-20) and year (x = years, y = amount of funding, stacked bar chart)

# %%
all_companies.head(10)
grpby_year_funding = all_companies.groupby('founded_year').sum()
grpby_year_funding
# grpby_year_funding.sort('founded_year',ascending=False).head(10)
# grpby_year_funding.sort('founded_year',ascending=False).head(20).plot(legend=False,title="Top 10 categories in acquisitions", kind="bar")
# plt.xticks(rotation=45)
# Out:
#               funding_rounds  funding_total_usd
# founded_year
# 0                      10566       188565062047
# 1903                       1            9300000
# 1906                       5         1134800000
# 1908                       2            5814700
# 1910                       1                  0
# 1911                       1            2400000
# 1912                       4          129700000
# 1913                       1           19000000
# 1914                       3           33300000
# 1917                       1          300000000
# 1918                       1             157000
# 1919                       6           52037845
# 1920                       1            2500000
# 1921                       1           35000000
# 1922                       2          209000000
# 1923                       3           39452366
# 1924                       7          870383014
# 1925                       1             154320
# 1926                       2             807000
# 1928                       4          125080000
# 1930                       7          409219399
# 1933                       1             150768
# 1934                       2          120000000
# 1937                       2              75000
# 1939                       1            7500000
# 1941                       1            1414100
# 1943                       3           17720000
# 1944                       1            5000000
# 1945                       2            4800000
# 1946                       1          412000000
# 1947                       2           44000000
# 1948                       7           53109610
# 1949                       1            2000000
# 1950                       1           28500000
# 1952                       6          186238920
# 1953                       1           12000002
# 1954                       7          165181916
# 1955                       3           57700000
# 1956                       1           12000000
# 1957                       1                  0
# 1958                       3           19600000
# 1959                       4          615112500
# 1960                       4           18887899
# 1961                      10          241257627
# 1962                       1            6000000
# 1963                      10         1039205631
# 1964                       4            2800000
# 1965                       1            4351345
# 1966                       5          110800000
# 1967                      11          205565000
# 1968                       8          401879926
# 1969                      22          161809366
# 1970                       5           41552002
# 1971                       7          104497287
# 1972                      10           63999376
# 1973                      12          441258490
# 1974                      12           86194154
# 1975                      16          100799282
# 1976                      15          452670832
# 1977                      12           25765316
#                          ...                ...
#
# [97 rows x 2 columns]

# %% [markdown]
# Number of acquisitions/exit by acquired company category (top 10-20) and year (x = years, y = count of acquisitions, stacked bar chart)

# %% [markdown]
# Comparison of 2 categories over time (line chart, x = year, y = total funding for all events for companies in that category, two lines 1 for each)

# %% [markdown]
# Comparison of 2 categories over time (bar chart, x = year, y = total # of exits in that category, two bars for each year)

# %% [markdown]
# Are companies acquiring in the same category or not? 2 lines in the chart, x = year, y = count of acquisitions where they have the same category, count where they are different

# %% [markdown]
# <br>/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////<br><br>

# %% [markdown]
# <h1 style="font-size:20px;line-height:0px;margin-bottom:10px;text-transform:uppercase;color:#3376A3">5 / Conclusions</h1>

# %% [markdown]
# Blahblahblah
